# %% [markdown]
# ### import all libraries

# %%
# %pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\ranee\miniconda3\lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\ranee\miniconda3\lib\site-packages (from scikit-learn) (2.4.1)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\ranee\miniconda3\lib\site-packages (from scikit-learn) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\ranee\miniconda3\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\ranee\miniconda3\lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
#Import svm model
from sklearn import svm

#Create a svm Classifier
clf = svm.SVC(kernel='linear') # Linear Kernel

#Train the model using the training sets
#Predict the response for test dataset

# %% [markdown]
# ### import dataset

# %% [markdown]
# ## SVM Classifier

# %% [markdown]
# ### generating the model

# %%
#Import svm model
from sklearn import svm

#Create a svm Classifier
clf = svm.SVC(kernel='linear') # Linear Kernel

#Train the model using the training sets
#clf.fit(X_train, y_train)

#Predict the response for test dataset
#y_pred = clf.predict(X_test)

# %% [markdown]
# ### evaluating the model

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics

# Model Accuracy: how often is the classifier correct?
#print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

# Model Precision: what percentage of positive tuples are labeled as such?
#print("Precision:",metrics.precision_score(y_test, y_pred))

# Model Recall: what percentage of positive tuples are labelled as such?
#print("Recall:",metrics.recall_score(y_test, y_pred))

# %% [markdown]
# ## Naive Bayes Classifier

# %% [markdown]
# ### generating the model

# %%
from sklearn.naive_bayes import GaussianNB

model = GaussianNB()

#model.fit(X_train, y_train);

# %% [markdown]
# ### evaluating the model

# %%
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    ConfusionMatrixDisplay,
    f1_score,
    classification_report,
)

#y_pred = model.predict(X_test)

#accuracy = accuracy_score(y_pred, y_test)
#f1 = f1_score(y_pred, y_test, average="weighted")

#print("Accuracy:", accuracy)
#print("F1 Score:", f1)

# %% [markdown]
# ## Logistic Regression Classifier

# %% [markdown]
# ### generating the model

# %%
# import the class
from sklearn.linear_model import LogisticRegression

# instantiate the model (using the default parameters)
logreg = LogisticRegression(random_state=16)

# fit the model with data
#logreg.fit(X_train, y_train)

#y_pred = logreg.predict(X_test)

# %% [markdown]
# ### evaluating the model

# %%
# import the metrics class
from sklearn import metrics

#cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
#cnf_matrix
from sklearn.metrics import classification_report
#target_names = [',']
#print(classification_report(y_test, y_pred, target_names=target_names))
